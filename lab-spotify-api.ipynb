# %%
# import required libs

import numpy as np
import pandas as pd
import sys
sys.path.insert(1, 'config.py')
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from time import sleep

# %%
# Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="3db44919272f4c3ba5af892352615609", client_secret="f87dfee302f4430d88ad1d44c842c4e6"))

# %%
# read the csvs into dataframes

hot_100 = pd.read_csv("hot100.csv")
not_hot = pd.read_csv("not_hot.csv")


display(hot_100.head())
display(not_hot.head())
# Out:
#                     Song                                Artist
# 0     Paint The Town Red                              Doja Cat
# 1                 Snooze                                   SZA
# 2               Fast Car                            Luke Combs
# 3           Cruel Summer                          Taylor Swift
# 4  I Remember Everything  Zach Bryan Featuring Kacey Musgraves
#    Unnamed: 0                track_id                      Artist  \
# 0      113186  6KwkVtXm8OUp2XffN5k7lY            Hillsong Worship
# 1       42819  2dp5I5MJ8bQQHDoFaNRFtX                Internal Rot
# 2       59311  5avw06usmFkFrPjX8NxC40  Zhoobin Askarieh;Ali Sasha
# 3       91368  75hT0hvlESnDJstem0JgyR                 Bryan Adams
# 4       61000  4bY2oZGA5Br3pTE1Jd1IfY                  Nogizaka46
#
#                         album_name                   Song  popularity  \
# 0                    No Other Name          No Other Name          50
# 1                   Grieving Birth         Failed Organum          11
# 2             Noise A Noise 20.4-1  Save the Trees, Pt. 1           0
# 3  All I Want For Christmas Is You        Merry Christmas           0
# 4                       バレッタ TypeD                  月の大きさ          57
#
#    duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 0       440247     False         0.369   0.598  ...    -6.984     1
# 1        93933     False         0.171   0.997  ...    -3.586     1
# 2       213578     False         0.173   0.803  ...   -10.071     0
# 3       151387     False         0.683   0.511  ...    -5.598     1
# 4       236293     False         0.555   0.941  ...    -3.294     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0304       0.00511          0.000000     0.176   0.0466  148.014
# 1       0.1180       0.00521          0.801000     0.420   0.0294  122.223
# 2       0.1440       0.61300          0.001910     0.195   0.0887   75.564
# 3       0.0279       0.40600          0.000197     0.111   0.5980  109.991
# 4       0.0481       0.48400          0.000000     0.266   0.8130   92.487
#
#    time_signature  track_genre
# 0               4  world-music
# 1               4    grindcore
# 2               3      iranian
# 3               3         rock
# 4               4       j-idol
#
# [5 rows x 21 columns]

# %%
# check that the duplicates have been deleted
print(not_hot.shape)
# Out:
# (2997, 21)

# %%
#drop cols apart from Song and Artist

not_hot = not_hot[['Song', 'Artist']]
display(not_hot.head())
# Out:
#                     Song                      Artist
# 0          No Other Name            Hillsong Worship
# 1         Failed Organum                Internal Rot
# 2  Save the Trees, Pt. 1  Zhoobin Askarieh;Ali Sasha
# 3        Merry Christmas                 Bryan Adams
# 4                  月の大きさ                  Nogizaka46

# %%
# check if the seach on Spotify works

song = sp.search(q="tracks: Distortion Sleep artist: Soilwork", limit=1) 
song['tracks']['items'][0]['id']
# Out:
# '3yPQrLnNIthn4I5wQ51X26'

# %%
#function to search for songs

def search_song(title, artist, limit=5):
    query = "tracks: "+title+" artist: "+artist
    try:
        result = sp.search(query, limit=limit)
        song_id = result['tracks']['items'][0]['id']
        return song_id
    except:
        return "not found"

# %%
# use the function to return a song ID
search_song("On My Mama", "Victoria Monet")
# Out:
# '1o8Z7GD1CeOaVBEyuzu4HO'

# %%
# add a new column 'Spotify_ID' to the hot_100 DataFrame
hot_100['Spotify_ID'] = hot_100.apply(lambda row: search_song(row['Song'], row['Artist']), axis=1)

# filter out rows with "not found" as Spotify_ID
hot_100 = hot_100[hot_100['Spotify_ID'] != "not found"]

# reset the index after filtering, you can do so
hot_100.reset_index(drop=True, inplace=True)
display(hot_100)
# Out:
#                      Song                                Artist  \
# 0      Paint The Town Red                              Doja Cat
# 1                  Snooze                                   SZA
# 2                Fast Car                            Luke Combs
# 3            Cruel Summer                          Taylor Swift
# 4   I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ..                    ...                                   ...
# 94     Standing Room Only                            Tim McGraw
# 95              Checkmate                              Rod Wave
# 96        Can't Have Mine                           Dylan Scott
# 97             On My Mama                        Victoria Monet
# 98   Love Is Embarrassing                        Olivia Rodrigo
#
#                 Spotify_ID
# 0   2IGMVunIBsBLtEQyoI1Mu7
# 1   4iZ4pt7kvcaH6Yo8UoZ4s2
# 2   1Lo0QY9cvc8sUB2vnIOxDT
# 3   2EGaDf0cPX789H3LNeB03D
# 4   4KULAymBBJcPRpk1yO4dOG
# ..                     ...
# 94  6BOP0cv1eeXcvi1oE8bDVZ
# 95  6VdBDm20nkyk6A29P785aJ
# 96  3jfywRZH6cB2iLyKqo4EZd
# 97  1o8Z7GD1CeOaVBEyuzu4HO
# 98  26QLJMK8G0M06sk7h7Fkse
#
# [99 rows x 3 columns]

# %%
# add a new column 'Spotify_ID' to the not_hot dataframe
not_hot['Spotify_ID'] = not_hot.apply(lambda row: search_song(row['Song'], row['Artist']), axis=1)

# filter out rows with "not found" as Spotify_ID
not_hot = not_hot[not_hot['Spotify_ID'] != "not found"]

# reset the index after filtering, you can do so
not_hot.reset_index(drop=True, inplace=True)
display(not_hot)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'tracks: Love Mashup artist: Shekhar Ravjiani;Shilpa Rao;Aakanksha Sharma;Ajay Gogavale;Amit Trivedi;Arijit Singh;Arko;Arnab Dutta;Ash King;Dev Negi;Farhan Saeed;Harshdeep Kaur;Neha Kakkar;Palak Muchhal;Shreya Ghoshal;Sunidhi Chauhan;Tony Kakkar;Yasser Desai;Ajay-Atul;Amjad Nadeem;Chirantan Bhat;Harish Sagane;JAM8;Pritam;Rochak Kohli;Shivam;Vishal-Shekhar;Dj Raahul Pai;Atif Aslam;Jyotica Tangri', 'limit': 5, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Bad request.
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'tracks: Almost Like Praying (feat. Artists for Puerto Rico) artist: Lin-Manuel Miranda;Alex Lacamoire;Ana Villafañe;Anthony Ramos;Artists for Puerto Rico;Camila Cabello;Dessa;Ednita Nazario;Fat Joe;Gilberto Santa Rosa;Gina Rodriguez;Gloria Estefan;Jennifer Lopez;Joell Ortiz;John Leguizamo;Juan Luis Guerra 4.40;Luis Fonsi;Marc Anthony;Pj Sin Suela;Pedro Capó;Rita Moreno;Rubén Blades;Tommy Torres', 'limit': 5, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Bad request.
#                        Song                              Artist  \
# 0             No Other Name                    Hillsong Worship
# 1            Failed Organum                        Internal Rot
# 2     Save the Trees, Pt. 1          Zhoobin Askarieh;Ali Sasha
# 3           Merry Christmas                         Bryan Adams
# 4                     月の大きさ                          Nogizaka46
# ...                     ...                                 ...
# 2985       Distortion Sleep                            Soilwork
# 2986       Proibida Pra Mim                        Zeca Baleiro
# 2987      相愛很難 - 電影"男人四十"歌曲              Jacky Cheung;Anita Mui
# 2988  The Girl From Ipanema  Antônio Carlos Jobim;Frank Sinatra
# 2989   All You Need Is Love                         The Beatles
#
#                   Spotify_ID
# 0     51AbDalUWkxCB1N0NZ3nU1
# 1     2dp5I5MJ8bQQHDoFaNRFtX
# 2     25RX0xcPBU4ZB1jMTRTu6g
# 3     6B8tOwbbbvRkGBrFw2PJB1
# 4     4bY2oZGA5Br3pTE1Jd1IfY
# ...                      ...
# 2985  3yPQrLnNIthn4I5wQ51X26
# 2986  5Te6AchmV1n93VD6DUDN3X
# 2987  09PZUuqCdaZi7KEIXdmoEQ
# 2988  5N6pQ2vYtd3Rb9w7LC8PZ9
# 2989  3HKK6kaPRwCTYlK5Quxoxh
#
# [2990 rows x 3 columns]

# %%
display(not_hot)
# Out:
#                        Song                              Artist  \
# 0             No Other Name                    Hillsong Worship
# 1            Failed Organum                        Internal Rot
# 2     Save the Trees, Pt. 1          Zhoobin Askarieh;Ali Sasha
# 3           Merry Christmas                         Bryan Adams
# 4                     月の大きさ                          Nogizaka46
# ...                     ...                                 ...
# 2985       Distortion Sleep                            Soilwork
# 2986       Proibida Pra Mim                        Zeca Baleiro
# 2987      相愛很難 - 電影"男人四十"歌曲              Jacky Cheung;Anita Mui
# 2988  The Girl From Ipanema  Antônio Carlos Jobim;Frank Sinatra
# 2989   All You Need Is Love                         The Beatles
#
#                   Spotify_ID
# 0     51AbDalUWkxCB1N0NZ3nU1
# 1     2dp5I5MJ8bQQHDoFaNRFtX
# 2     25RX0xcPBU4ZB1jMTRTu6g
# 3     6B8tOwbbbvRkGBrFw2PJB1
# 4     4bY2oZGA5Br3pTE1Jd1IfY
# ...                      ...
# 2985  3yPQrLnNIthn4I5wQ51X26
# 2986  5Te6AchmV1n93VD6DUDN3X
# 2987  09PZUuqCdaZi7KEIXdmoEQ
# 2988  5N6pQ2vYtd3Rb9w7LC8PZ9
# 2989  3HKK6kaPRwCTYlK5Quxoxh
#
# [2990 rows x 3 columns]

# %%
def get_audio_features(list_of_song_ids):
  
    """Collects audio features for a list of song IDs.

    Input:
    list_of_song_ids: A list of song IDs.

    Returns:
    pandas DataFrame containing the audio features for the IDs.
    """
    
    # split the list of song IDs into chunks of 50 to avoid hitting the rate limit.
    
    chunks = [list_of_song_ids[i:i + 50] for i in range(0, len(list_of_song_ids), 50)]

    # get audio features
    
    all_features = []
    for chunk in chunks:
        features_chunk = sp.audio_features(chunk)
        if features_chunk is not None:  # check if the result is not None.
            valid_features = [f for f in features_chunk if f is not None]
            all_features.extend(valid_features)
        else:
            print("Failed to fetch features for chunk:", chunk)

    # convert the list of dictionaries to df
    
    df_audio_features = pd.DataFrame(all_features)
    return df_audio_features

# %%
# get audio features for the hot songs

df_hot_audio_features = get_audio_features(hot_100['Spotify_ID'].tolist())

# merge frames

hot_100 = pd.merge(hot_100, df_hot_audio_features, left_on='Spotify_ID', right_on='id', how='left')

#drop duplicates

hot_100.drop_duplicates(subset=['Spotify_ID'], inplace=True)

# reindex
hot_100.reset_index(drop=True, inplace=True)

display(hot_100)
# Out:
#                      Song                                Artist  \
# 0      Paint The Town Red                              Doja Cat
# 1                  Snooze                                   SZA
# 2                Fast Car                            Luke Combs
# 3            Cruel Summer                          Taylor Swift
# 4   I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ..                    ...                                   ...
# 91     Standing Room Only                            Tim McGraw
# 92              Checkmate                              Rod Wave
# 93        Can't Have Mine                           Dylan Scott
# 94             On My Mama                        Victoria Monet
# 95   Love Is Embarrassing                        Olivia Rodrigo
#
#                 Spotify_ID  danceability  energy  key  loudness  mode  \
# 0   2IGMVunIBsBLtEQyoI1Mu7         0.868   0.538    5    -8.603     1
# 1   4iZ4pt7kvcaH6Yo8UoZ4s2         0.559   0.551    5    -7.231     1
# 2   1Lo0QY9cvc8sUB2vnIOxDT         0.712   0.603    8    -5.520     1
# 3   2EGaDf0cPX789H3LNeB03D         0.666   0.871    1    -6.017     0
# 4   4KULAymBBJcPRpk1yO4dOG         0.429   0.453    0    -7.746     1
# ..                     ...           ...     ...  ...       ...   ...
# 91  6BOP0cv1eeXcvi1oE8bDVZ         0.475   0.789    1    -6.124     1
# 92  6VdBDm20nkyk6A29P785aJ         0.731   0.622    5    -8.237     1
# 93  3jfywRZH6cB2iLyKqo4EZd         0.663   0.502    5    -7.070     1
# 94  1o8Z7GD1CeOaVBEyuzu4HO         0.481   0.539    4    -7.865     0
# 95  26QLJMK8G0M06sk7h7Fkse         0.520   0.831    9    -3.432     1
#
#     speechiness  acousticness  ...  liveness  valence    tempo  \
# 0        0.1740       0.26900  ...    0.0901    0.732   99.968
# 1        0.1320       0.14100  ...    0.1100    0.392  143.008
# 2        0.0262       0.18600  ...    0.1150    0.670   97.994
# 3        0.0272       0.27000  ...    0.2630    0.936  108.501
# 4        0.0459       0.55400  ...    0.1020    0.155   77.639
# ..          ...           ...  ...       ...      ...      ...
# 91       0.0380       0.17000  ...    0.1470    0.485  155.227
# 92       0.0979       0.17600  ...    0.1530    0.445   82.494
# 93       0.0285       0.79100  ...    0.1050    0.371  143.969
# 94       0.1080       0.55100  ...    0.1200    0.621  153.277
# 95       0.0968       0.00261  ...    0.1560    0.677  160.035
#
#               type                      id  \
# 0   audio_features  2IGMVunIBsBLtEQyoI1Mu7
# 1   audio_features  4iZ4pt7kvcaH6Yo8UoZ4s2
# 2   audio_features  1Lo0QY9cvc8sUB2vnIOxDT
# 3   audio_features  2EGaDf0cPX789H3LNeB03D
# 4   audio_features  4KULAymBBJcPRpk1yO4dOG
# ..             ...                     ...
# 91  audio_features  6BOP0cv1eeXcvi1oE8bDVZ
# 92  audio_features  6VdBDm20nkyk6A29P785aJ
# 93  audio_features  3jfywRZH6cB2iLyKqo4EZd
# 94  audio_features  1o8Z7GD1CeOaVBEyuzu4HO
# 95  audio_features  26QLJMK8G0M06sk7h7Fkse
#
#                                      uri  \
# 0   spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 1   spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 2   spotify:track:1Lo0QY9cvc8sUB2vnIOxDT
# 3   spotify:track:2EGaDf0cPX789H3LNeB03D
# 4   spotify:track:4KULAymBBJcPRpk1yO4dOG
# ..                                   ...
# 91  spotify:track:6BOP0cv1eeXcvi1oE8bDVZ
# 92  spotify:track:6VdBDm20nkyk6A29P785aJ
# 93  spotify:track:3jfywRZH6cB2iLyKqo4EZd
# 94  spotify:track:1o8Z7GD1CeOaVBEyuzu4HO
# 95  spotify:track:26QLJMK8G0M06sk7h7Fkse
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 1   https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 2   https://api.spotify.com/v1/tracks/1Lo0QY9cvc8s...
# 3   https://api.spotify.com/v1/tracks/2EGaDf0cPX78...
# 4   https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ..                                                ...
# 91  https://api.spotify.com/v1/tracks/6BOP0cv1eeXc...
# 92  https://api.spotify.com/v1/tracks/6VdBDm20nkyk...
# 93  https://api.spotify.com/v1/tracks/3jfywRZH6cB2...
# 94  https://api.spotify.com/v1/tracks/1o8Z7GD1CeOa...
# 95  https://api.spotify.com/v1/tracks/26QLJMK8G0M0...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2IGM...      231750
# 1   https://api.spotify.com/v1/audio-analysis/4iZ4...      201800
# 2   https://api.spotify.com/v1/audio-analysis/1Lo0...      265493
# 3   https://api.spotify.com/v1/audio-analysis/2EGa...      215326
# 4   https://api.spotify.com/v1/audio-analysis/4KUL...      227196
# ..                                                ...         ...
# 91  https://api.spotify.com/v1/audio-analysis/6BOP...      226091
# 92  https://api.spotify.com/v1/audio-analysis/6VdB...      198034
# 93  https://api.spotify.com/v1/audio-analysis/3jfy...      183087
# 94  https://api.spotify.com/v1/audio-analysis/1o8Z...      186678
# 95  https://api.spotify.com/v1/audio-analysis/26QL...      154517
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 91               4
# 92               4
# 93               4
# 94               4
# 95               4
#
# [96 rows x 21 columns]

# %%
# get audio features for the not hot songs

df_not_hot_audio_features = get_audio_features(not_hot['Spotify_ID'].tolist())

# merge frames

not_hot = pd.merge(not_hot, df_not_hot_audio_features, left_on='Spotify_ID', right_on='id', how='left')

# drop duplicates
not_hot.drop_duplicates(subset=['Spotify_ID'], inplace=True)

# reindex
not_hot.reset_index(drop=True, inplace=True)

display(not_hot)
# Out:
#                             Song                      Artist  \
# 0                  No Other Name            Hillsong Worship
# 1                 Failed Organum                Internal Rot
# 2          Save the Trees, Pt. 1  Zhoobin Askarieh;Ali Sasha
# 3                Merry Christmas                 Bryan Adams
# 4                          月の大きさ                  Nogizaka46
# ...                          ...                         ...
# 2850  Extraño - Versión Acústica                    Miranda!
# 2851            Distortion Sleep                    Soilwork
# 2852            Proibida Pra Mim                Zeca Baleiro
# 2853           相愛很難 - 電影"男人四十"歌曲      Jacky Cheung;Anita Mui
# 2854        All You Need Is Love                 The Beatles
#
#                   Spotify_ID  danceability  energy  key  loudness  mode  \
# 0     51AbDalUWkxCB1N0NZ3nU1         0.358   0.613  7.0    -6.452   1.0
# 1     2dp5I5MJ8bQQHDoFaNRFtX         0.171   0.997  7.0    -3.586   1.0
# 2     25RX0xcPBU4ZB1jMTRTu6g         0.586   0.757  6.0    -6.861   1.0
# 3     6B8tOwbbbvRkGBrFw2PJB1         0.497   0.463  6.0    -7.465   1.0
# 4     4bY2oZGA5Br3pTE1Jd1IfY         0.555   0.941  9.0    -3.294   0.0
# ...                      ...           ...     ...  ...       ...   ...
# 2850  6az5WAcx20hzYkvSDOkj7n         0.731   0.567  7.0    -6.862   1.0
# 2851  3yPQrLnNIthn4I5wQ51X26         0.368   0.949  2.0    -6.178   1.0
# 2852  5Te6AchmV1n93VD6DUDN3X         0.650   0.361  7.0   -10.614   1.0
# 2853  09PZUuqCdaZi7KEIXdmoEQ         0.448   0.730  0.0    -4.000   1.0
# 2854  3HKK6kaPRwCTYlK5Quxoxh         0.421   0.377  7.0    -8.457   1.0
#
#       speechiness  acousticness  ...  liveness  valence    tempo  \
# 0          0.0308      0.005640  ...    0.1460   0.0481  148.002
# 1          0.1180      0.005210  ...    0.4200   0.0294  122.223
# 2          0.0299      0.173000  ...    0.1440   0.1840  120.036
# 3          0.0272      0.714000  ...    0.1460   0.4680   73.318
# 4          0.0481      0.484000  ...    0.2660   0.8130   92.487
# ...           ...           ...  ...       ...      ...      ...
# 2850       0.0376      0.779000  ...    0.0726   0.8180  118.001
# 2851       0.1410      0.000078  ...    0.0341   0.3470  160.270
# 2852       0.0328      0.722000  ...    0.0970   0.5400  132.839
# 2853       0.0385      0.526000  ...    0.1230   0.4500  134.037
# 2854       0.0393      0.921000  ...    0.1790   0.4350  116.120
#
#                 type                      id  \
# 0     audio_features  51AbDalUWkxCB1N0NZ3nU1
# 1     audio_features  2dp5I5MJ8bQQHDoFaNRFtX
# 2     audio_features  25RX0xcPBU4ZB1jMTRTu6g
# 3     audio_features  6B8tOwbbbvRkGBrFw2PJB1
# 4     audio_features  4bY2oZGA5Br3pTE1Jd1IfY
# ...              ...                     ...
# 2850  audio_features  6az5WAcx20hzYkvSDOkj7n
# 2851  audio_features  3yPQrLnNIthn4I5wQ51X26
# 2852  audio_features  5Te6AchmV1n93VD6DUDN3X
# 2853  audio_features  09PZUuqCdaZi7KEIXdmoEQ
# 2854  audio_features  3HKK6kaPRwCTYlK5Quxoxh
#
#                                        uri  \
# 0     spotify:track:51AbDalUWkxCB1N0NZ3nU1
# 1     spotify:track:2dp5I5MJ8bQQHDoFaNRFtX
# 2     spotify:track:25RX0xcPBU4ZB1jMTRTu6g
# 3     spotify:track:6B8tOwbbbvRkGBrFw2PJB1
# 4     spotify:track:4bY2oZGA5Br3pTE1Jd1IfY
# ...                                    ...
# 2850  spotify:track:6az5WAcx20hzYkvSDOkj7n
# 2851  spotify:track:3yPQrLnNIthn4I5wQ51X26
# 2852  spotify:track:5Te6AchmV1n93VD6DUDN3X
# 2853  spotify:track:09PZUuqCdaZi7KEIXdmoEQ
# 2854  spotify:track:3HKK6kaPRwCTYlK5Quxoxh
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/51AbDalUWkxC...
# 1     https://api.spotify.com/v1/tracks/2dp5I5MJ8bQQ...
# 2     https://api.spotify.com/v1/tracks/25RX0xcPBU4Z...
# 3     https://api.spotify.com/v1/tracks/6B8tOwbbbvRk...
# 4     https://api.spotify.com/v1/tracks/4bY2oZGA5Br3...
# ...                                                 ...
# 2850  https://api.spotify.com/v1/tracks/6az5WAcx20hz...
# 2851  https://api.spotify.com/v1/tracks/3yPQrLnNIthn...
# 2852  https://api.spotify.com/v1/tracks/5Te6AchmV1n9...
# 2853  https://api.spotify.com/v1/tracks/09PZUuqCdaZi...
# 2854  https://api.spotify.com/v1/tracks/3HKK6kaPRwCT...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/51Ab...    440253.0
# 1     https://api.spotify.com/v1/audio-analysis/2dp5...     93933.0
# 2     https://api.spotify.com/v1/audio-analysis/25RX...    183568.0
# 3     https://api.spotify.com/v1/audio-analysis/6B8t...    150697.0
# 4     https://api.spotify.com/v1/audio-analysis/4bY2...    236293.0
# ...                                                 ...         ...
# 2850  https://api.spotify.com/v1/audio-analysis/6az5...    232672.0
# 2851  https://api.spotify.com/v1/audio-analysis/3yPQ...    225933.0
# 2852  https://api.spotify.com/v1/audio-analysis/5Te6...    195000.0
# 2853  https://api.spotify.com/v1/audio-analysis/09PZ...    224893.0
# 2854  https://api.spotify.com/v1/audio-analysis/3HKK...    129947.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 2850             4.0
# 2851             4.0
# 2852             4.0
# 2853             4.0
# 2854             4.0
#
# [2855 rows x 21 columns]

# %% [markdown]
# Add HOT/NOT column to datasets:

# %%
#Add values HOT/NOT to new column 'hot' using on id of song

not_hot['hot'] = not_hot['id'].dt.year #?
not_hot.head()

hot_100['hot'] = hot_100['id'].dt.year #?
hot_100.head()

# %%
hot_100_featured = hot_100.copy()

hot_100_featured.to_csv('extended_hot_100.csv', index=False)

# %%
hot_100_featured = not_hot.copy()

not_hot_featured.to_csv('extended_not_hot.csv', index=False)

# %%
#hot_100_featured = hot_100.copy()

#hot_100_featured.to_csv('hot100.csv', index=False)

# %%
#not_hot_featured = not_hot.copy()

#not_hot_featured.to_csv('hot100.csv', index=False)
